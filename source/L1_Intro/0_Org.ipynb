# %% [markdown]
# <img src ="http://fmb.images.gan4x4.ru/msu/intro/intro-01.jpg" >
# <img src ="http://fmb.images.gan4x4.ru/msu/intro/intro-02.jpg" >

# %% [markdown]
# ## Организационные вопросы

# %% [markdown]
# * Средства связи, контакты
# * Ссылки на данные и литературу
# * Где скачать лекции
# * Критерии и инструменты оценки результатов
# * Требования к слушателям

# %% [markdown]
# # Ссылки на литературу
#
# Х. Бринк "Real world machine learning
#
# ELI STEVENS, LUCA ANTIGA, AND THOMAS VIEHMANN Deep Learning with PyTorch
